# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("mark_sheet_dataset_clean.csv")
df.T
# Out:
#                     0          1          2          3          4     \
# Student_ID         S1001      S1002      S1003      S1004      S1005
# Gender            Female       Male     Female     Female     Female
# Math_Score     79.967142  73.617357  81.476885  90.230299  72.658466
# English_Score  86.792265  81.095604  70.715564  62.236759   78.37868
# Science_Score  72.598574  76.843851  71.660641  75.536308  62.851083
# Attendance     75.460962  80.698075  82.931972  94.438438  87.782766
#
#                     5          6          7          8          9     ...  \
# Student_ID         S1006      S1007      S1008      S1009      S1010  ...
# Gender              Male     Female     Female       Male       Male  ...
# Math_Score     75.264884  90.792128  82.674347  70.305256    80.4256  ...
# English_Score  74.721825  80.742319  77.622062  82.594633  63.577177  ...
# Science_Score   79.70635  78.009644  71.463291  83.273965  85.500561  ...
# ...

# %%
print("First 5 records:")
print(df.head())
# Out:
# First 5 records:
#   Student_ID  Gender  Math_Score  English_Score  Science_Score  Attendance
# 0      S1001  Female   79.967142      86.792265      72.598574   75.460962
# 1      S1002    Male   73.617357      81.095604      76.843851   80.698075
# 2      S1003  Female   81.476885      70.715564      71.660641   82.931972
# 3      S1004  Female   90.230299      62.236759      75.536308   94.438438
# 4      S1005  Female   72.658466      78.378680      62.851083   87.782766

# %%
print("\nDataset Information:")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     1005 non-null   str
#  1   Gender         1006 non-null   str
#  2   Math_Score     1006 non-null   float64
#  3   English_Score  1006 non-null   float64
#  4   Science_Score  1006 non-null   float64
#  5   Attendance     1006 non-null   float64
# dtypes: float64(4), str(2)
# memory usage: 47.3 KB
# None

# %%
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#         Math_Score  English_Score  Science_Score   Attendance
# count  1006.000000    1006.000000    1006.000000  1006.000000
# mean     75.198142      70.874313      78.023826    84.886866
# std       9.820832      12.055850       7.897920     5.176507
# min      45.060838      34.331165      53.609156    68.820336
# 25%      68.537904      62.731719      72.802663    81.254154
# 50%      75.262897      70.765309      77.949680    84.970576
# 75%      81.476885      78.811820      83.258518    88.326472
# max     105.378940     107.424099     102.433148   100.897548

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Student_ID       1
# Gender           0
# Math_Score       0
# English_Score    0
# Science_Score    0
# Attendance       0
# dtype: int64
